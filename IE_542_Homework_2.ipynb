# %% [markdown]
# <a href="https://colab.research.google.com/github/jdrake13/IE-542/blob/main/IE_542_Homework_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the packages

import numpy as np
import matplotlib.pyplot as plt

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
#independency and correlation
import pandas as pd
from pandas.plotting import scatter_matrix
df = pd.DataFrame(X) #transfer the matrix X into the pandas default data frame

# %%
data = np.loadtxt('IE 542_Homework 2_Dataset.txt')
X = np.loadtxt('IE 542_Homework 2_Dataset.txt', usecols = (0,1,2))
Y = np.loadtxt('IE 542_Homework 2_Dataset.txt', usecols= (3,4,5))
print(X)
# Out:
# [[ 1.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 9.17267920e-01  2.68908050e-01  1.28836000e-03]
#  [ 8.67205480e-01  5.16543140e-01  4.74304000e-03]
#  [ 8.45066010e-01  7.51596320e-01  1.00194700e-02]
#  [ 8.47330300e-01  9.81514760e-01  1.70506700e-02]
#  [ 8.71485370e-01  1.21282282e+00  2.59822600e-02]
#  [ 9.15852360e-01  1.45138546e+00  3.71418400e-02]
#  [ 9.79454060e-01  1.70262599e+00  5.10327600e-02]
#  [ 1.06191415e+00  1.97170778e+00  6.83467000e-02]
#  [ 1.16338221e+00  2.26368750e+00  8.99925000e-02]
#  [ 1.28447949e+00  2.58364570e+00  1.17140560e-01]
#  [ 1.42626144e+00  2.93679875e+00  1.51283880e-01]
#  [ 1.59019393e+00  3.32859489e+00  1.94318000e-01]
#  [ 1.77814010e+00  3.76479503e+00  2.48643330e-01]
#  [ 1.99235559e+00  4.25153760e+00  3.17294230e-01]
#  [ 2.23548945e+00  4.79538411e+00  4.04100630e-01]
#  [ 2.51058826e+00  5.40333947e+00  5.13888440e-01]
#  [ 2.82110013e+00  6.08283757e+00  6.52726250e-01]
#  [ 3.17087472e+00  6.84167740e+00  8.28225700e-01]
#  [ 3.56415381e+00  7.68788921e+00  1.04990223e+00]
#  [ 4.00554545e+00  8.62950118e+00  1.32960065e+00]
#  [ 4.49997165e+00  9.67416758e+00  1.68198443e+00]
#  [ 5.05257667e+00  1.08286061e+01  2.12507741e+00]
#  [ 5.66857782e+00  1.20977776e+01  2.68082883e+00]
#  [ 6.35303636e+00  1.34837298e+01  3.37564511e+00]
#  [ 7.11051906e+00  1.49840159e+01  4.24078693e+00]
#  [ 7.94461617e+00  1.65896046e+01  5.31246789e+00]
#  [ 8.85727770e+00  1.82822298e+01  6.63140769e+00]
#  [ 9.84793218e+00  2.00312098e+01  8.24149027e+00]
#  [ 1.09123653e+01  2.17899210e+01  1.01870784e+01]
#  [ 1.20413676e+01  2.34923772e+01  1.25084797e+01]
#  [ 1.32192207e+01  2.50507462e+01  1.52351274e+01]
#  [ 1.44221876e+01  2.63551026e+01  1.83763439e+01]
#  [ 1.56173017e+01  2.72771229e+01  2.19102353e+01]
#  [ 1.67618943e+01  2.76795045e+01  2.57723747e+01]
#  [ 1.78044019e+01  2.74322114e+01  2.98473301e+01]
#  [ 1.86869729e+01  2.64348592e+01  3.39672359e+01]
#  [ 1.93501423e+01  2.46416947e+01  3.79215765e+01]
#  [ 1.97393254e+01  2.20825931e+01  4.14801903e+01]
#  [ 1.98121808e+01  1.88720651e+01  4.44270556e+01]
#  [-8.74713778e+00 -9.83234410e+00  2.62508856e+01]
#  [-8.85388056e+00 -9.88090338e+00  2.64179135e+01]
#  [-8.95435200e+00 -9.91532471e+00  2.65943728e+01]
#  [-9.04774280e+00 -9.93454621e+00  2.67781199e+01]
#  [-9.13322978e+00 -9.93772251e+00  2.69668521e+01]
#  [-9.20999934e+00 -9.92425310e+00  2.71581367e+01]
#  [-9.27727134e+00 -9.89380666e+00  2.73494450e+01]
#  [-9.33432271e+00 -9.84634018e+00  2.75381937e+01]
#  [-9.38051033e+00 -9.78211118e+00  2.77217912e+01]
#  [-9.41529252e+00 -9.70168192e+00  2.78976871e+01]
#  [-9.43824837e+00 -9.60591484e+00  2.80634235e+01]
#  [-9.44909440e+00 -9.49595873e+00  2.82166862e+01]
#  [-9.44769785e+00 -9.37322573e+00  2.83553530e+01]
#  [-9.43408596e+00 -9.23936020e+00  2.84775378e+01]
#  [-9.40845118e+00 -9.09619975e+00  2.85816284e+01]]

# %%
np.mean(X),np.mean(Y)
# Out:
# (7.641188695099999, 3.070201911966665)

# %%
x1 = np.loadtxt('IE 542_Homework 2_Dataset.txt', usecols= (0))
x2 = np.loadtxt('IE 542_Homework 2_Dataset.txt', usecols= (1))
x3 = np.loadtxt('IE 542_Homework 2_Dataset.txt', usecols= (2))
y1 = np.loadtxt('IE 542_Homework 2_Dataset.txt', usecols= (3))
y2 = np.loadtxt('IE 542_Homework 2_Dataset.txt', usecols= (4))
y3 = np.loadtxt('IE 542_Homework 2_Dataset.txt', usecols= (5))

# %%
np.mean(y1)
# Out:
# -10.3409862724

# %%
np.std(x2)
# Out:
# 11.694778693579648

# %%
#import the dataset from scikit-learn package
from sklearn import datasets
#import the dataset
X, Y = datasets.load_diabetes(return_X_y=True)
# this loads the diabetes data as #X is the input matrix as in the slides, and y is the output vector

# %%
df = pd.DataFrame(x1)
scatter_matrix(df, alpha = 0.2, figsize = (10, 10), diagonal = 'kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2bddffea50>]],
#       dtype=object)

# %%
df = pd.DataFrame(x2)
scatter_matrix(df, alpha = 0.2, figsize = (10, 10), diagonal = 'kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2bddf83d10>]],
#       dtype=object)

# %%
df = pd.DataFrame(x3)
scatter_matrix(df, alpha = 0.2, figsize = (10, 10), diagonal = 'kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2bde039a10>]],
#       dtype=object)

# %%
#least squares
#here only shows a demo of using one variable
#i.e., this is simple linear regression
first_X = X[:,0] #we first use only one variable
first_X = first_X[:,np.newaxis] #reshape the vector as a matrix

#then we split the data (X and y) into training and testing
#take the last 40 data points as the test data
#the rest are training data
first_X_train = first_X[:80]
first_X_test = first_X[80:]

y_train = Y[:80]
y_test = Y[80:]

#ls is the least square method
ls = linear_model.LinearRegression(fit_intercept = False)
ls.fit(first_X_train,y_train)
print(ls.intercept_, ls.coef_)

#predict the test data
y_predict = ls.predict(first_X_test)

#mean squared error and R squared
print('Mean suqared error:%.2f'
     # %mean_squared_error(y_test,y_predict))
print('R squared:%.2f'
     # %r2_score(y_test,y_predict))


#plot the predict against the real
plt.figure(1)
plt.xlabel('First variable')
plt.ylabel('Response y')
plt.title('Simple linear regression')
plt.scatter(first_X_test, y_test,color='blue')
plt.plot(first_X_test,y_predict,color='red')
plt.show()
# Out:
# 0.0 [-332.55982213]
# Mean suqared error:31096.76
# R squared:-4.09
